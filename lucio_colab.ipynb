# %% [markdown]
# # Lucio Challenge - Colab Execution Notebook
# Follow these steps to run the pipeline on Google Colab:
# 1. Upload `lucio.zip` using the Files panel on the left (Folder icon -> Upload icon).
# 2. Wait for the upload to complete.
# 3. Run the cells below one by one.

# %%
# Cell 1: Unzip the project and install dependencies
# !unzip -q lucio.zip -d lucio
# %cd lucio
# !pip install -r requirements.txt
# !pip install google-genai openpyxl pandas httpx

# %%
# Cell 2: Verify the .env file is present and has the API key
# !cat .env

# %%
# Cell 3: Run the submission script to process all documents and answer the questions
# !python submit.py

# %% [markdown]
# **Done!** When Cell 3 finishes, you will see `lucio_submission.json` inside the `lucio` folder on the left. You can right-click it and download it.
